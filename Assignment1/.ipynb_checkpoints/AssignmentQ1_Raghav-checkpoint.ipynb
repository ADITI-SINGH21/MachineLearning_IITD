# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statistics

# %%
df_1 = pd.read_excel('data_1.xlsx')

# %%
df_1.plot.scatter(x = 'x', y = 'y')
print('The scatter plot for data 1')
plt.show()
# Out:
# The scatter plot for data 1

# %%
pd.DataFrame(df_1).plot.hist()
print('Histogram Plot for data 1')
plt.show()
# Out:
# Histogram Plot for data 1

# %%
sns.heatmap(pd.DataFrame(df_1))
print('Heat map for 1st data')
plt.show()
# Out:
# Heat map for 1st data

# %%
sns.boxplot(x=df_1.x)
print('Boxplot for 1st column')
plt.show()
# Out:
# Boxplot for 1st column

# %%
sns.boxplot(x=df_1.y)
print('Boxplot for 2nd column')
plt.show()
# Out:
# Boxplot for 2nd column

# %%
df_3 = pd.read_excel('data_3.xlsx')

# %%
df_3.plot.scatter(x = 'x', y = 'y')
print('Scatter Plot for data 3')
plt.show()
# Out:
# Scatter Plot for data 3

# %%
pd.DataFrame(df_3).plot.hist()
print('Histogram Plot for Data3 column x')
plt.show()
# Out:
# Histogram Plot for Data3 column x

# %%
sns.heatmap(pd.DataFrame(df_3))
print('Heat map for 2nd data')
plt.show()
# Out:
# Heat map for 2nd data

# %%
sns.boxplot(x=df_3.x)
plt.title('Box Plot for x column 2nd data')
# Out:
# Text(0.5, 1.0, 'Box Plot for x column 2nd data')

# %%
sns.boxplot(x=df_3.y)
plt.title('Box Plot for y column 2nd data')
# Out:
# Text(0.5, 1.0, 'Box Plot for y column 2nd data')

# %%
print('The statistics for first data are')
print(df_1.describe())
# Out:
# The statistics for first data are
#                 x           y
# count  500.000000  500.000000
# mean     4.939743    5.042984
# std      0.986803    1.008197
# min      2.373638    2.181180
# 25%      4.303987    4.331464
# 50%      4.924278    5.074768
# 75%      5.607214    5.682380
# max      8.117045    8.190109

# %%
print('The statistics for second data are')
print(df_3.describe())
# Out:
# The statistics for second data are
#                 x           y
# count  500.000000  500.000000
# mean     5.082468    4.952896
# std      1.631735    1.623194
# min     -1.458403   -1.004100
# 25%      4.318981    4.218101
# 50%      5.054875    4.978847
# 75%      5.891603    5.782668
# max     12.267025   10.589252

# %%
print('Using standard deviation approach the outliers are')
z_score = np.abs(stats.zscore(df_3))
arrayx=[]
arrayy=[]
for i in range(len(df_3)):
    if z_score[:,0][i]>3:
        arrayx.append(np.array(df_3)[:,0][i])
    if z_score[:,1][i]>3:
        arrayx.append(np.array(df_3)[:,1][i])
print(arrayx)
print(arrayy)
# Out:
# Using standard deviation approach the outliers are
# [10.10393747643514, 10.43902165955905, 10.67798532964827, 12.2670245277286, 10.55061243676815, 11.44965456902049, 10.58925243952102, 10.28782093813039, 10.11551641326384, -1.458402520742969, -1.171853375119153, -0.763132811291513, -0.2198563833130491, -0.5334956955315495, -0.2557338130229054, -0.2439263484483771, -1.004100360593079, -0.5528195925039532]
# []

# %%
print('Using MAD approach the outliers are')
def zm_score(df):
    Median = statistics.median(df)
    MAD = statistics.median(np.abs(df-Median))
    Z_modified = 0.6745*(df-Median)/MAD
    return Z_modified
ax=[]
ay=[]
z1 = zm_score(df_3.x)
z2 = zm_score(df_3.y)
for i in range(len(df_3)):
    if z1[i]>3:
        ax.append(np.array(df_3)[:,0][i])
    if z2[i]>3:
        ay.append(np.array(df_3)[:,1][i])
print(ax)
print(ay)
# Out:
# Using MAD approach the outliers are
# [9.745989964192137,
#  9.265264240840457,
#  10.43902165955905,
#  9.219071559753377,
#  9.717401494534483,
#  8.5540601585995,
#  10.55061243676815,
#  9.749970745029252,
#  9.127858533076473,
#  8.581245337617629,
#  8.529730294461498,
#  10.58925243952102,
#  8.693157145943976,
#  9.431652444355333,
#  10.11551641326384]
